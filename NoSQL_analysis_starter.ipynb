# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
uk_food = mongo['uk_food']

# %%
# review the collections in our database
print(uk_food.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establish_food = uk_food['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene': 20}

# Use count_documents to display the number of documents in the result
print("Number of documents in result:", establish_food.count_documents(query))

# Display the first document in the results using pprint
print("First result:")
results = establish_food.find(query)
pprint(results[0])
# Out:
# Number of documents in result: 41
# First result:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63f18d20ea2b670113fe3036'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
# ...

# %%
# Convert the result to a Pandas DataFrame

# Display the number of rows in the DataFrame

# Display the first 10 rows of the DataFrame
hygiene_df = pd.DataFrame(results)

print("Rows in DataFrame: ", len(hygiene_df))
hygiene_df.head(10)
# Out:
# Rows in DataFrame:  41
#                         _id   FHRSID  ChangesByServerID  \
# 0  63f18d20ea2b670113fe3036   110681                  0
# 1  63f18d20ea2b670113fe33b7   612039                  0
# 2  63f18d20ea2b670113fe36be   730933                  0
# 3  63f18d20ea2b670113fe38ac   172735                  0
# 4  63f18d20ea2b670113fe38bd   172953                  0
# 5  63f18d20ea2b670113fe425d   512854                  0
# 6  63f18d20ea2b670113fe447e  1537089                  0
# 7  63f18d20ea2b670113fe59a9   155648                  0
# 8  63f18d20ea2b670113fe5dec  1012883                  0
# 9  63f18d20ea2b670113fe6601   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
london = {'LocalAuthorityName': {'$regex':'London'}, 'RatingValue': {'$gte': '4'} }

# Use count_documents to display the number of documents in the result
print("Number of documents in result:", establish_food.count_documents(london))

# Display the first document in the results using pprint
print("First result:")
results = establish_food.find(london)
pprint(results[0])
# Out:
# Number of documents in result: 34
# First result:
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': '4',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('63f18d20ea2b670113fe4a51'),
#  'geocode': {'latitude': 51.369321, 'longitude': 0.508551},
# ...

# %%
# Convert the result to a Pandas DataFrame

# Display the number of rows in the DataFrame

# Display the first 10 rows of the DataFrame
london_df = pd.DataFrame(results)

print("Rows in DataFrame: ", len(london_df))
london_df.head(10)
# Out:
# Rows in DataFrame:  34
#                         _id   FHRSID  ChangesByServerID  \
# 0  63f18d20ea2b670113fe4a51   621707                  0
# 1  63f18d20ea2b670113fe4d78  1130836                  0
# 2  63f18d20ea2b670113fe58c6   293783                  0
# 3  63f18d20ea2b670113fe66c5  1315095                  0
# 4  63f18d20ea2b670113fe66c6   294474                  0
# 5  63f18d20ea2b670113fe6dcd   294900                  0
# 6  63f18d20ea2b670113fe8ed6  1252616                  0
# 7  63f18d20ea2b670113fe8edb   293756                  0
# 8  63f18d20ea2b670113fe92a5   878523                  0
# 9  63f18d20ea2b670113fe92be   293772                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of '5', sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.083812
longitude = 1.195625



query = {'geocode.latitude': {'$gte':latitude-degree_search, '$lte':latitude+degree_search}, 
         'geocode.longitude': {'$gte': longitude-degree_search, '$lte': longitude+degree_search},
         'RatingValue': '5'}

sort = ('score.Hygiene', 1)
limit = 5

# Print the results

pprint(list(establish_food.find(query).sort(sort).limit(limit)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [18], in <cell line: 20>()
#      16 limit = 5
#      18 # Print the results
# ---> 20 pprint(list(establish_food.find(query).sort(sort).limit(limit)))
#
# File ~\anaconda3\lib\site-packages\pymongo\cursor.py:874, in Cursor.sort(self, key_or_list, direction)
#     872 self.__check_okay_to_chain()
#     873 keys = helpers._index_list(key_or_list, direction)
# --> 874 self.__ordering = helpers._index_document(keys)
#     875 return self
#
# File ~\anaconda3\lib\site-packages\pymongo\helpers.py:111, in _index_document(index_list)
#     108     raise ValueError("key_or_list must not be the empty list")
#     110 index: SON[str, Any] = SON()
# --> 111 for (key, value) in index_list:
#     112     if not isinstance(key, str):
#     113         raise TypeError("first item in each key pair must be an instance of str")
#
# ...

# %%
# Convert result to Pandas DataFrame

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest
match_query = {'$match': {'scores.Hygiene': 0 }}

group_query = {'$group': {'_id':'$LocalAuthorityName', 'count': { '$sum': 1 }}}

sort_values = {'$sort': { 'count': -1}}

pipeline = [match_query, group_query, sort_values]

results = list(establish_food.aggregate(pipeline))


# Print the number of documents in the result
print("Number of classifications in result: ", len(results))

# %%
# Print the first 10 results
pprint(results[0:10])

# %%
# Convert the result to a Pandas DataFrame

# Display the number of rows in the DataFrame

# Display the first 10 rows of the DataFrame
local_hygiene_zero_df = pd.DataFrame(results)

print("Rows in DataFrame: ", len(local_hygiene_zero_df))
local_hygiene_zero_df.head(10)
